# %%
# Sociocultural impacts are also regarded as important factors in justifying 
# investment into hosting mega-events.19 Such events can ‘provide a 
# catalyst to upskill the current labour force of the host nation,’ 20,21 
# which in turn may lead to ‘enhanced educational standards within the 
# broader population, improved employability, and the development of 
# transferable skills which can be utilised in future work, *volunteering*
# endeavours, and other areas of life.’ 20,22 Additionally, existing research 
# suggests that ‘volunteering at a mega-event results in a positive social legacy 
# and promotes continued volunteering after the conclusion of the event.’ 20,23

# %%
# A number of studies have revealed a positive correlation between mega-events
# and residents’ levels of *civic pride* in the host country.20 Similarly, social capital
# —the set of shared values or resources that facilitates collaboration within a 
# community—has been found to increase following a mega-event due to ‘increased 
# perceptions of quality of life and well-being,’ 20,24 in addition to ‘reinforced 
# community spirit, heightened national identity and enhanced social unity.’ 20,25 
# However, mega-events can also have a negative impact on social capital, 
# especially in instances where the event results in ‘*traffic congestion, noise, increased 
# crime, or other anti-social behaviour and cultural conflicts*.’ 20,26 The 
# displacement of homeless and other marginalised populations has also been found 
# to be a negative social capital impact.20,27

# %%
import matplotlib.pyplot as plt
  
months = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec',' Jan']

# line 1 points
social_security_beneficiaries = [14240,14334,14312,14382,14281,14436,14495,14514,14452,13978,14074,14168,14281]

# plotting the line 1 points 
plt.plot(months, social_security_beneficiaries, label = "Social Security Beneficiaries")

# line 2 points
#population = [2791925, 2811774, 2826286, 2773598, 2852886, 2657333, 2658311, 2937800, 2985029, 3020080, 2891345, 2909134, 2954947]

# plotting the line 2 points
#plt.plot(months, population, label = "Population")

x0 = ['Nov', 'Dec']
y0 = [14074,14168]
plt.plot(x0, y0, "s")
  
# naming the x axis
plt.xlabel('Month')
# naming the y axis
plt.ylabel('Individuals')
# giving a title to my graph
plt.title('Social Security Beneficiaries Jan 2022 - Jan 2023')
  
# show a legend on the plot
plt.legend()
  
# function to show the plot
plt.show()

# %%
# Exploitation of workers in preparation for the 2010 CWG was
# common, involving ‘low pay, unsafe working conditions, lack of housing, use of child
# labour, non-registration of workers, and
# denial of social security benefits’ (Mishra et al., 2010: 3).

# %%
import matplotlib.pyplot as plt
  
months = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec',' Jan']

# line 1 points
y1 = [79532,78503,78051,77904,78665,78535,78350,78651,78020,75791,76998,77528,78110]

# plotting the line 1 points 
plt.plot(months, y1, label = "Social Security Value")

x0 = ['Nov', 'Dec']
y0 = [76998,77528]
plt.plot(x0, y0, "s")
  
# naming the x axis
plt.xlabel('Month')
# naming the y axis
plt.ylabel('Million QAR')
# giving a title to my graph
plt.title('Social Security Value Jan 2022 - Jan 2023')
  
# show a legend on the plot
plt.legend()
  
# function to show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
  
years = [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030]

plt.axvline(x=2020)

germany = [27623.6, 27801.0, 29032.6, 35344.6, 39448.3, 40077.5, 41125.0, 45805.8, 49532.5, 46526.6, 45263.5, 50140.8, 47256.1, 49356.6, 50196.1, 42550.8, 43653.0, 45552.1, 49582.6, 48004.9, 49296.5, 52423.2, 51304.3, 52758.9, 53304.0, 55587.6, 57790.9, 59851.7, 61993.4, 64208.5, 66430.3]
plt.plot(years, germany, label = "Germany")
x0 = [2006]
y0 = [41125.0]
plt.plot(x0, y0, "s")

south_africa = [4264.8, 3606.6, 3231.8, 4760.7, 6145.5, 6708.4, 6727.8, 7138.6, 6494.5, 6739.4, 8507.2, 9074.3, 8427.6, 7621.7, 7122.8, 6342.6, 5692.2, 6527.9, 6728.5, 6279.7, 5303.6, 6275.3, 6044.5, 5979.6, 6267.0, 6370.4, 6475.7, 6600.1, 6754.6, 6931.5, 7149.1]
plt.plot(years, south_africa, label = "South Africa")
x1 = [2010]
y1 = south_africa[6]
plt.plot(x1, y1, "s")

brazil = [5768.4, 4763.2, 4163.5, 4495.5, 5181.2, 6710.7, 8293.8, 10247.1, 12120.7, 12232.5, 15614.4, 18403.9, 17441.1, 17316.4, 17473.3, 12770.3, 12966.3, 14982.4, 13524.5, 12033.2, 10232.0, 10634.4, 12684.5, 13520.3, 14466.0, 15257.5, 16052.5, 16804.1, 17542.6, 18265.0, 18954.2]
plt.plot(years, brazil, label = "Brazil")
x2 = [2014]
y2 = brazil[14]
plt.plot(x2, y2, "s")

russia = [1872.6, 2347.1, 2915.2, 3555.6, 4778.2, 6054.5, 7635.5, 9813.5, 12622.0, 10566.4, 12462.0, 14989.5, 16064.2, 17320.0, 15825.3, 10606.3, 10132.1, 12293.4, 11988.3, 12416.0, 10697.1, 12576.8, 14676.6, 14131.8, 14881.8, 15276.7, 15666.9, 16110.2, 16623.0, 17186.3, 17787.7]
plt.plot(years, russia, label = "Russia")
x3 = [2018]
y3 = russia[18]
plt.plot(x3, y3, "s")

qatar = [32924.9, 33983.2, 38610.8, 42104.3, 34900.4, 44691.9, 53845.2, 58864.4, 64262.6, 62812.0, 56116.7, 75160.5, 77169.9, 79404.2, 69441.7, 70150.1, 64181.8, 61353.5, 61613.8, 62759.8, 54975.8, 63640.0, 66494.9, 70675.9, 72279.6, 75204.6, 77697.2, 81022.0, 84787.8, 88946.7, 93376.7]
plt.plot(years, qatar, label = "Qatar")
x4 = [2022]
y4 = qatar[22]
plt.plot(x4, y4, "s")
  
# naming the x axis
plt.xlabel('Year')
# naming the y axis
plt.ylabel('USD')
# giving a title to my graph
plt.title('Median Disposable Household Income 2000 - 2030')
  
# show a legend on the plot
plt.legend()
  
# function to show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
  
years = [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030]

plt.axvline(x=2020)

germany = [34.1, 34.1, 34.2, 34.2, 34.2, 34.3, 34.0, 33.9, 34.2, 34.3, 34.2, 34.2, 34.3, 34.3, 34.3, 34.4, 34.4, 34.4, 34.4, 34.4, 34.5, 34.5, 34.5, 34.5, 34.5, 34.5, 34.5, 34.5, 34.5, 34.5, 34.6]
plt.plot(years, germany, label = "Germany")
x0 = [2006]
y0 = germany[6]
plt.plot(x0, y0, "s")

south_africa = [63.5, 63.6, 63.6, 63.6, 63.6, 63.6, 63.6, 63.6, 63.9, 63.9, 63.4, 63.2, 63.4, 63.1, 63.0, 63.2, 63.2, 63.3, 63.3, 63.4, 63.4, 63.5, 63.6, 63.7, 63.8, 63.9, 64.0, 64.0, 64.1, 64.1, 64.1]
plt.plot(years, south_africa, label = "South Africa")
x1 = [2010]
y1 = south_africa[6]
plt.plot(x1, y1, "s")

brazil = [56.7, 56.6, 56.3, 55.5, 54.8, 54.7, 54.0, 53.0, 52.3, 51.8, 52.2, 52.9, 53.5, 52.8, 52.1, 51.9, 53.3, 53.3, 53.9, 53.4, 51.4, 53.4, 53.8, 53.7, 53.6, 53.5, 53.3, 53.2, 53.0, 52.9, 52.8]
plt.plot(years, brazil, label = "Brazil")
x2 = [2014]
y2 = brazil[14]
plt.plot(x2, y2, "s")

russia = [39.5, 39.7, 39.7, 40.3, 40.9, 40.9, 41.5, 42.2, 42.1, 42.1, 42.1, 41.7, 42.0, 41.8, 41.6, 41.2, 41.2, 41.1, 41.3, 41.1, 41.1, 41.0, 40.9, 40.9, 40.9, 40.9, 40.8, 40.8, 40.8, 40.8, 40.8]
plt.plot(years, russia, label = "Russia")
x3 = [2018]
y3 = russia[18]
plt.plot(x3, y3, "s")

qatar = [37.1, 37.4, 37.7, 38.0, 38.2, 38.4, 38.6, 38.8, 39.0, 39.3, 39.7, 40.0, 40.4, 40.6, 40.8, 40.9, 41.0, 41.1, 41.2, 41.3, 41.4, 41.5, 41.5, 41.6, 41.6, 41.7, 41.7, 41.7, 41.8, 41.8, 41.8]
plt.plot(years, qatar, label = "Qatar")
x4 = [2022]
y4 = qatar[22]
plt.plot(x4, y4, "s")
  
# naming the x axis
plt.xlabel('Year')
# naming the y axis
plt.ylabel('Gini Coefficient')
# giving a title to my graph
plt.title('Gini Coefficient 2000 - 2030')
  
# show a legend on the plot
plt.legend()
  
# function to show the plot
plt.show()

# %%
# 61% of Qataris, 75% of white-collar expatriates and 79% of blue
# collar expatriates said they are very or somewhat interested in
# volunteering during the FIFA World Cup in Qatar 2022. 

# 400,000+ volunteer registrations received
# 20,000 volunteers selected from 150 nationalities
# 17,000 volunteers were Qatar residents

# %%
import matplotlib.pyplot as plt
  
months = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec',' Jan']

# line 1 points
y1 = [214248, 206258, 228833, 208204, 238176, 193132, 190133, 204105,  239990, 203437, 118117, 76160, 135839]

# plotting the line 1 points 
plt.plot(months, y1, label = "Total Traffic Violations")

x0 = ['Nov', 'Dec']
y0 = [118117,76160]
plt.plot(x0, y0, "s")
  
# naming the x axis
plt.xlabel('Month')
# naming the y axis
plt.ylabel('Incidents')
# giving a title to my graph
plt.title('Total Traffic Violations Jan 2022 - Jan 2023')
  
# show a legend on the plot
plt.legend()
  
# function to show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
  
months = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec',' Jan']

# line 1 points
y1 = [717, 682, 810, 695, 822, 746, 629, 685, 803, 880, 866, 991, 788]


# plotting the line 1 points 
plt.plot(months, y1, label = "Total Traffic Accidents")

x0 = ['Nov', 'Dec']
y0 = [866,991]
plt.plot(x0, y0, "s")
  
# naming the x axis
plt.xlabel('Month')
# naming the y axis
plt.ylabel('Incidents')
# giving a title to my graph
plt.title('Total Traffic Accidents Jan 2022 - Jan 2023')
  
# show a legend on the plot
plt.legend()
  
# function to show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
  
years = ['2023','Mid 2022','2022','Mid 2021','2021','Mid 2020','2020','Mid 2019','2019','Mid 2018','2018','Mid 2017','2017','Mid 2016','2016','Mid 2015','2015','Mid 2014','2014']

y1 = [14.5,14.0,13.8,11.9,12.0,11.5,11.5,11.7,12.2,13.1,14.5,15.9,16.6,21.1,22.8,20.5,21.3,23.1,22.1]
y2 = [85.5,86.0,86.2,89.1,88,88.5,88.5,88.3,87.8,86.9,85.5,84.1,83.4,78.9,77.2,79.5,78.7,76.9,77.9]

# plotting the line 1 points 
plt.figure(figsize=(15,6))
plt.plot(years, y1, label = "Crime Index")
plt.plot(years, y2,  label = "Safety Index")
  
# naming the x axis
plt.xlabel('Year')
# naming the y axis
plt.ylabel('Crime/Safety Index')
# giving a title to my graph
plt.title('Crime/Safety Index Jan 2022 - Jan 2023')
  
# show a legend on the plot
plt.legend()
  
# function to show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
  
x = [1,2,3]
y = [61, 75, 79]
tick_label = ['Qatari Nationals', 'White-Collar Expatriates', 'Blue-Collar Expatriates']


# plotting the line 1 points 
plt.figure(figsize=(10,6))
plt.bar(x, y, tick_label = tick_label,
        width = 0.8)
  
# naming the x axis
plt.xlabel('Demographic')
# naming the y axis
plt.ylabel('Percentage')
# giving a title to my graph
plt.title('Reported Interest in Volunteering for the 2022 FIFA World Cup 2018-2019')
  
# show a legend on the plot
  
# function to show the plot
plt.show()
